# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols

# t = time measuring in milisekund
# mx_visual(t) - three dimensional matrix with visual information 
# mx_sound(t) - three dimensional matrix with sound information
# mx_feel(t) - three dimensional matrix with feel information
# mx_taste(t) - three dimensional matrix with taste information
# mx_smell(t) - three dimensional matrix with smell information
# pi_eyes(t) - information potential flowing in milisecond by organ of sight
# pi_hear(t) - information potential flowing in milisecond by organ of hearing
# pi_touch(t) - information potential flowing in milisecond by organ of touch
# pi_taste(t) - information potential flowing in milisecond by organ of taste
# pi_smell(t) - information potential flowing in milisecond by organ of smell

pi_eyes(mx_eyes(t))(t) = tanh()











# classic parameter
Cm = 1.0 # uF/cm^2
# classic g parameters
gNa = 120.0 # mS/cm^2
gk = 36.0 # ms/cm^2
gl = 0.3 # ms/cm^2
# classic e parameters
eNa = 50.0 # mV
eK = -77.0 # mV
eL = -54.387 # mV
